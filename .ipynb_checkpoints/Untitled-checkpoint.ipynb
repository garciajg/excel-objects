# %%
import pandas as pd

# %%
EXCEL_DATA = "building_data.xlsx"

sheet = pd.read_excel(EXCEL_DATA)#, sheet_name="Sheet1", names=[
#     "date_added",
#     "occupancy",
#     "lease_signed",
#     "building",
#     "building_class",
#     "city",
#     "deal_size",
#     "tenant",
#     "new_renewal_expansion",
#     "term",
#     "base_rent",
#     "rent_structure",
#     "esc",
#     "t_i",
#     "rent_abatement",
#     "tenant_broker",
#     "ll_broker",
#     "t_o",
#     "comments"])

sheet.head()
# Out:
#             Date Added Occupancy Lease Signed  \
# 0  2016-05-10 00:00:00   2Q 2019      1Q 2016
# 1  2017-04-26 00:00:00   1Q 2019      1Q 2017
# 2  2017-01-24 00:00:00   3Q 2018      1Q 2017
# 3  2017-05-02 00:00:00   1Q 2018      2Q 2017
# 4  2017-05-16 00:00:00   4Q 2017      1Q 2017
#
#                                       Building Building Class  \
# 0             Commerce Plaza\n2015 Spring Road              A
# 1         Corporate Lakes IV\n2300 Cabot Drive          A-/B+
# 2  Westings Corp. Center\n2056 Westings Avenue              A
# 3                          2 Mid America Plaza              A
# 4                             999 Oakmont Lane              B
#
#                City Deal Size                     Tenant  \
# 0         Oak Brook     18541                Sterigenics
# 1             Lisle     13359              Ice Miller LP
# 2        Naperville     25083                Wells Fargo
# 3  Oakbrook Terrace      4434           King-Devick Test
# ...

# %%
inp = input("Enter a category:")
list_of_inputs = inp.strip().split(",")
print(list_of_inputs)
custom_sheet = sheet[list_of_inputs]
# custom_sheet = sheet[["Building", "{}".format(str(inp))]]
custom_sheet.head()
# Out:
# Enter a category:City, Building, Deal Size
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f9f2ae444d4d> in <module>
#       1 inp = input("Enter a category:")
# ----> 2 list_of_inputs = inp.split(",").strip()
#       3 print(list_of_inputs)
#       4 custom_sheet = sheet[list_of_inputs]
#       5 # custom_sheet = sheet[["Building", "{}".format(str(inp))]]
#
# AttributeError: 'list' object has no attribute 'strip'
